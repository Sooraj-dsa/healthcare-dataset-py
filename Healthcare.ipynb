# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
a.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
a.all()
# Out:
# id                    True
# gender                True
# age                   True
# hypertension         False
# heart_disease        False
# ever_married          True
# work_type             True
# Residence_type        True
# avg_glucose_level     True
# bmi                   True
# smoking_status        True
# stroke               False
# dtype: bool

# %%
a.notnull()
# Out:
#         id  gender   age  hypertension  heart_disease  ever_married  \
# 0     True    True  True          True           True          True
# 1     True    True  True          True           True          True
# 2     True    True  True          True           True          True
# 3     True    True  True          True           True          True
# 4     True    True  True          True           True          True
# ...    ...     ...   ...           ...            ...           ...
# 5105  True    True  True          True           True          True
# 5106  True    True  True          True           True          True
# 5107  True    True  True          True           True          True
# 5108  True    True  True          True           True          True
# 5109  True    True  True          True           True          True
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# 0          True            True               True   True            True
# ...

# %%
a.dropna()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
a.drop_duplicates()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
a.corr()
# Out:
# <ipython-input-11-210c353a220b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.003084  0.006388
# ...

# %%
a.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
pd.DataFrame(a)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
a.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
a=a.replace(' ',np.nan)

# %%
a.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
from itertools import groupby
sns.histplot(data=a,x='avg_glucose_level',bins=18,hue=a['Residence_type'])
plt.show()

# %%
sns.displot(data=a,x='heart_disease',y='avg_glucose_level',hue=a['work_type'])
plt.yticks(rotation=60)
plt.show()

# %%
sns.barplot(data=a,x='smoking_status',y='age',hue=a['gender'])
plt.show()

# %%
b=a.groupby(['hypertension','gender'])

# %%
b.get_group((1,'Male'))
# Out:
#          id gender   age  hypertension  heart_disease ever_married  \
# 6     53882   Male  74.0             1              1          Yes
# 17    34120   Male  75.0             1              0          Yes
# 30    43717   Male  57.0             1              0          Yes
# 44     7937   Male  60.0             1              0          Yes
# 45    19824   Male  76.0             1              0          Yes
# ...     ...    ...   ...           ...            ...          ...
# 4952  16245   Male  51.0             1              0          Yes
# 4983  10995   Male  76.0             1              0          Yes
# 4987  67012   Male  64.0             1              0          Yes
# 5091   6369   Male  59.0             1              0          Yes
# 5100  68398   Male  82.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 6           Private          Rural              70.09  27.4   never smoked
# ...

# %%
sns.violinplot(data=a,x='ever_married',y='heart_disease',hue=a['hypertension'])
plt.show()

# %%
a['bmi'].value_counts()
# Out:
# 28.7    41
# 28.4    38
# 26.7    37
# 27.6    37
# 26.1    37
#         ..
# 48.7     1
# 49.2     1
# 51.0     1
# 49.4     1
# 14.9     1
# Name: bmi, Length: 418, dtype: int64

# %%
import seaborn as sns
#print(sns.get_dataset_names())
c_df=sns.load_dataset('flights')
c_df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
pd.DataFrame(c_df)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.boxplot(data=c_df,x='month',y='year')
plt.show()

# %%
sns.set_theme(style="ticks")

c_df = sns.load_dataset("flights")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=c_df,
    x="passengers", y="year",
    hue="month",color="align",
    kind="line", size_order=["T1", "T2"], palette=palette,
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)
# Out:
# <ipython-input-26-cbf9dc2eaf68>:9: UserWarning:
# The palette list has fewer values (6) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.relplot(

# %%
sns.lineplot(data=a,x='age',y='bmi',hue=a['stroke'],palette='Reds')
plt.show()

# %%
a.iloc[25:40+1,1:3+1]
# Out:
#     gender   age  hypertension
# 25    Male  80.0             0
# 26  Female  65.0             0
# 27    Male  58.0             0
# 28    Male  69.0             0
# 29    Male  59.0             0
# 30    Male  57.0             1
# 31    Male  42.0             0
# 32  Female  82.0             1
# 33    Male  80.0             0
# 34    Male  48.0             0
# 35  Female  82.0             1
# 36    Male  74.0             0
# 37  Female  72.0             1
# 38    Male  58.0             0
# 39  Female  49.0             0
# 40    Male  78.0             0

# %%
a.loc[25:40,'gender':'hypertension']
# Out:
#     gender   age  hypertension
# 25    Male  80.0             0
# 26  Female  65.0             0
# 27    Male  58.0             0
# 28    Male  69.0             0
# 29    Male  59.0             0
# 30    Male  57.0             1
# 31    Male  42.0             0
# 32  Female  82.0             1
# 33    Male  80.0             0
# 34    Male  48.0             0
# 35  Female  82.0             1
# 36    Male  74.0             0
# 37  Female  72.0             1
# 38    Male  58.0             0
# 39  Female  49.0             0
# 40    Male  78.0             0

# %%
a['age'].value_counts()[50]
# Out:
# 83

# %%
a.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
a.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...
